# %%
run Read_sessantaquattroplus.py
# Out:
# Starting to log data: 72 channels with 2000 sampling rate
# number of channels 72
# waiting for connection...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/gitworks/phd/ReWire/Rewire_Project/Regrasp_2nd/Read_sessantaquattroplus.py:215
#     213 print("number of channels " + str(number_of_channels))
#     214 # Open connection to Sessantaquattro
# --> 215 connection = communication.connect_to_sq(sq_socket, ip_address, port, start_command)
#     217 last_time = {0: time.time()}
#     219 lines = []
#
# File ~/Documents/gitworks/phd/ReWire/Rewire_Project/Regrasp_2nd/communication.py:187, in connect_to_sq(sq_socket, ip_address, port, start_command)
#     185 sq_socket.listen(1)
#     186 print('waiting for connection...')
# --> 187 conn, addr = sq_socket.accept()
#     188 print('Connection from address: {0}'.format((addr)))
#     189 conn.send(start_command)
# ...
